# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nest-competition/eligibilities.txt
# /kaggle/input/nest-competition/facilities_cleaned.csv
# /kaggle/input/nest-competition/eligibilities_cleaned.csv
# /kaggle/input/nest-competition/drop_withdrawals_cleaned.csv
# /kaggle/input/nest-competition/reported_events.txt
# /kaggle/input/nest-competition/facilities.txt
# /kaggle/input/nest-competition/usecase_2_.csv
# /kaggle/input/nest-competition/drop_withdrawals.txt

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/nest-competition/usecase_2_.csv')
df = df.rename(columns={"NCT Number": "nct_id"})
facilities = pd.read_csv('/kaggle/input/nest-competition/facilities.txt', sep='|')
facilities.head()
# Out:
#          id       nct_id      status                                     name  \
# 0  39182239  NCT02696421  RECRUITING  Imperial College London Diabetes Centre
# 1  39182240  NCT01324414         NaN                              Mayo Clinic
# 2  39182241  NCT02595814         NaN              Novartis Investigative Site
# 3  39182242  NCT02595814         NaN              Novartis Investigative Site
# 4  39182243  NCT02595814         NaN              Novartis Investigative Site
#
#             city       state         zip               country
# 0      Abu Dhabi         NaN       48338  United Arab Emirates
# 1        Phoenix     Arizona       85054         United States
# 2      San Diego  California       92103         United States
# 3  San Francisco  California  94143-0780         United States
# 4        Chicago    Illinois       60611         United States

# %%
df.shape
# Out:
# (68960, 26)

# %%
facilities.shape
# Out:
# (3085464, 8)

# %%
# Perform an inner merge to keep only the rows in drop_withdrawals where nct_id is in df
facilities = facilities.merge(df[['nct_id']], on='nct_id', how='inner')
facilities.shape
# Out:
# (398949, 8)

# %%
facilities.drop_duplicates(keep="first", inplace=True)
facilities.shape
# Out:
# (398949, 8)

# %%
facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398949 entries, 0 to 398948
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       398949 non-null  int64
#  1   nct_id   398949 non-null  object
#  2   status   755 non-null     object
#  3   name     380534 non-null  object
#  4   city     398949 non-null  object
#  5   state    227890 non-null  object
#  6   zip      343198 non-null  object
#  7   country  398949 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 24.4+ MB

# %%
df['Study Status'].unique()
# Out:
# array(['COMPLETED'], dtype=object)

# %%
facilities['status'].unique()
# Out:
# array([nan, 'NOT_YET_RECRUITING', 'RECRUITING', 'ENROLLING_BY_INVITATION',
#        'COMPLETED', 'ACTIVE_NOT_RECRUITING', 'WITHDRAWN', 'TERMINATED'],
#       dtype=object)

# %%
facilities = facilities.drop(['id', 'status'], axis='columns')

# %%
facilities.head()
# Out:
#         nct_id name               city state  zip country
# 0  NCT02889796  NaN           Nowa Sól   NaN  NaN  Poland
# 1  NCT02889796  NaN             Poznan   NaN  NaN  Poland
# 2  NCT02889796  NaN             Poznań   NaN  NaN  Poland
# 3  NCT02889796  NaN  Tomaszów Lubelski   NaN  NaN  Poland
# 4  NCT02889796  NaN              Toruń   NaN  NaN  Poland

# %%
facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398949 entries, 0 to 398948
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   nct_id   398949 non-null  object
#  1   name     380534 non-null  object
#  2   city     398949 non-null  object
#  3   state    227890 non-null  object
#  4   zip      343198 non-null  object
#  5   country  398949 non-null  object
# dtypes: object(6)
# memory usage: 18.3+ MB

# %%
# facilities.iloc[50:100]

# %%
# Step 1: Compute modes
zip_mode_per_city = facilities.dropna(subset=['zip']).groupby('city')['zip'].agg(lambda x: x.mode()[0])
state_mode_per_city = facilities.dropna(subset=['state']).groupby('city')['state'].agg(lambda x: x.mode()[0])
country_mode_per_state = facilities.dropna(subset=['country']).groupby('state')['country'].agg(lambda x: x.mode()[0])
name_mode_per_nct_id = facilities.dropna(subset=['name']).groupby('nct_id')['name'].agg(lambda x: x.mode()[0])

# Step 2: Replace mismatched or NaN values
# Replace all mismatched or NaN state values for a given city with the mode state
facilities['zip'] = facilities.apply(lambda row: zip_mode_per_city[row['city']] if row['city'] in zip_mode_per_city else row['zip'], axis=1)

# Replace all mismatched or NaN state values for a given city with the mode state
facilities['state'] = facilities.apply(lambda row: state_mode_per_city[row['city']] if row['city'] in state_mode_per_city else row['state'], axis=1)

# Replace all mismatched or NaN country values for a given state with the mode country
facilities['country'] = facilities.apply(lambda row: country_mode_per_state[row['state']] if row['state'] in country_mode_per_state else row['country'], axis=1)

# Replace only NaN name values for a given nct_id with the mode name
facilities['name'] = facilities['name'].fillna(facilities['nct_id'].map(name_mode_per_nct_id))

# %%
facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398949 entries, 0 to 398948
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   nct_id   398949 non-null  object
#  1   name     382663 non-null  object
#  2   city     398949 non-null  object
#  3   state    380252 non-null  object
#  4   zip      395949 non-null  object
#  5   country  398949 non-null  object
# dtypes: object(6)
# memory usage: 18.3+ MB

# %%
# Step 1: Pre-calculate modes for all relevant columns
mode_df = facilities.dropna(subset=['zip', 'city', 'name', 'state', 'country']).groupby('nct_id').agg({
    'zip': lambda x: x.mode()[0] if not x.mode().empty else None,
    'city': lambda x: x.mode()[0] if not x.mode().empty else None,
    'name': lambda x: x.mode()[0] if not x.mode().empty else None,
    'state': lambda x: x.mode()[0] if not x.mode().empty else None,
    'country': lambda x: x.mode()[0] if not x.mode().empty else None
}).rename(columns={
    'zip': 'mode_zip',
    'city': 'mode_city',
    'name': 'mode_name',
    'state': 'mode_state',
    'country': 'mode_country'
})

# Step 2: Count unique values efficiently
unique_counts = facilities.groupby('nct_id').agg({
    'name': lambda x: x.nunique(dropna=False),
    'state': lambda x: x.nunique(dropna=False),
    'zip': lambda x: x.nunique(dropna=False),
    'city': 'nunique',
    'country': 'nunique'
}).rename(columns={
    'name': 'unique_name_count',
    'state': 'unique_state_count',
    'zip': 'unique_zip_count',
    'city': 'unique_city_count',
    'country': 'unique_country_count'
})

# Step 3: Merge modes and counts into a single DataFrame
final_counts = mode_df.join(unique_counts, on='nct_id').reset_index()

# Output: Check the final DataFrame
print(final_counts.head())

# Optional: Save the result to a file
# final_counts.to_csv('nct_id_counts_modes.csv', index=False)
# Out:
#         nct_id mode_zip   mode_city  \
# 0  NCT00323141     9000       Ghent
# 1  NCT00737893    21287   Baltimore
# 2  NCT00862433    20892    Bethesda
# 3  NCT00900809    15213  Pittsburgh
# 4  NCT01066234    03080       Seoul
#
#                                        mode_name         mode_state  \
# 0                      University Hospital Ghent    Oost-Vlaanderen
# 1                         Johns Hopkins Hospital           Maryland
# 2  National Institutes of Health Clinical Center           Maryland
# 3     UPMC Cancer Center - Hillman Cancer Center       Pennsylvania
# 4                         Samsung Medical Center  Seoul Teugbyeolsi
#
#          mode_country  unique_name_count  unique_state_count  \
# 0             Belgium                  1                   1
# 1       United States                  1                   1
# 2       United States                  1                   1
# 3       United States                  1                   1
# 4  Korea, Republic of                  1                   1
#
#    unique_zip_count  unique_city_count  unique_country_count
# 0                 1                  1                     1
# 1                 1                  1                     1
# 2                 1                  1                     1
# 3                 1                  1                     1
# 4                 1                  1                     1

# %%
final_counts.head(50)
# Out:
#          nct_id   mode_zip                mode_city  \
# 0   NCT00323141       9000                    Ghent
# 1   NCT00737893      21287                Baltimore
# 2   NCT00862433      20892                 Bethesda
# 3   NCT00900809      15213               Pittsburgh
# 4   NCT01066234      03080                    Seoul
# 5   NCT01113515      02903                  Chennai
# 6   NCT01229631    1105 AZ                Amsterdam
# 7   NCT01267448      60611                  Chicago
# 8   NCT01288573      00168                Amsterdam
# 9   NCT01290055      30030                  Decatur
# 10  NCT01376167      10400                  Bangkok
# 11  NCT01380938      00168                     Roma
# 12  NCT01395641        100                   Taipei
# 13  NCT01398319      78236  Lackland Air Force Base
# 14  NCT01406392  50070-550                   Recife
# 15  NCT01410890     115478                   Moscow
# 16  NCT01420627      10467                    Bronx
# 17  NCT01420887      55905                Rochester
# 18  NCT01439412       0424                     Oslo
# 19  NCT01450826      27710                   Durham
# 20  NCT01484340       2571               Klerksdorp
# 21  NCT01494038        267                Cape Town
# 22  NCT01495819      06516               West Haven
# 23  NCT01511640      40536                Lexington
# 24  NCT01529554      10117              Bad Nauheim
# 25  NCT01550107    DD1 9SY                   Dundee
# 26  NCT01590017       +263                   Harare
# 27  NCT01600131      32610              Gainesville
# 28  NCT01605383      08035                Barcelona
# 29  NCT01609842      10016              Albuquerque
# 30  NCT01614197      02114                Ann Arbor
# 31  NCT01630590      77030                  Houston
# 32  NCT01632891       +256                 Blantyre
# 33  NCT01641107      00168                     Roma
# 34  NCT01653405      01730                  Bedford
# 35  NCT01657448  05403-000                São Paulo
# 36  NCT01657760      90073         West Los Angeles
# 37  NCT01665677      26506                Milwaukee
# 38  NCT01666756      91010                   Duarte
# 39  NCT01670552  13060-080                 Campinas
# 40  NCT01671904      34295                  Detroit
# 41  NCT01690988      63110              Saint Louis
# 42  NCT01701193      61039                  Kharkiv
# 43  NCT01707030      94143                Palo Alto
# 44  NCT01715909      28040                   Madrid
# 45  NCT01716312      20892                 Bethesda
# 46  NCT01722149       8091                   Zurich
# 47  NCT01730664    9713 GZ                Groningen
# 48  NCT01736124      10467                    Bronx
# 49  NCT01737281      10016                  Houston
#
#                                             mode_name           mode_state  \
# 0                           University Hospital Ghent      Oost-Vlaanderen
# 1                              Johns Hopkins Hospital             Maryland
# 2       National Institutes of Health Clinical Center             Maryland
# 3          UPMC Cancer Center - Hillman Cancer Center         Pennsylvania
# 4                              Samsung Medical Center    Seoul Teugbyeolsi
# 5     Deenanath Mangeshkar Hospital & Research Center          Maharashtra
# 6                       Academic Centre for Dentistry              Alabama
# 7                John Stroger Hospital of Cook County             Illinois
# 8                      Investigational Site Number 11              Alabama
# 9             The Hope Clinic of Emory Vaccine Center              Georgia
# 10                           GSK Investigational Site             Amazonas
# 11                              Gastroenterology Unit                Lazio
# 12                National Taiwan University Hospital       Neihu District
# 13                                37th Training Group                Texas
# 14  Instituto de Medicina Integral Professor Ferna...           Pernambuco
# 15                   Investigational Site Number 1028               Moskva
# 16                Albert Einstein College of Medicine           California
# 17                           Mayo Clinic in Rochester            Minnesota
# 18  Institute of Health and Society, Faculty of Me...            Lørenskog
# 19  The Preston Robert Tisch Brain Tumor Center at...       North Carolina
# 20              Grace Mokhomo Community Health Center           North West
# 21     Byramjee Jeejeebhoy Medical College (BJMC) CRS  South-East District
# 22                     Department of Veterans Affairs          Connecticut
# 23        Laboratory of Human Behavioral Pharmacology             Kentucky
# 24                                Cardiocentro Ticino                   BE
# 25                University of Dundee Medical School             Scotland
# 26  Clinical HIV Research Unit, a Division of the ...            Belgravia
# 27       James A. Haley Veterans' Hospital, Tampa, FL              Florida
# 28                Hospital Universitari Vall d'Hebron            Catalunya
# 29   Atlanta VA Medical and Rehab Center, Decatur, GA                 Ohio
# 30               British Columbia Children's Hospital           California
# 31      University of Texas MD Anderson Cancer Center                Texas
# 32  AMPATH at Moi Univ. Teaching Hosp. Eldoret CRS...              Central
# 33  ASL Le/1 P.O. Vito Fazzi - U.O. di Ematologia ...       Emilia-Romagna
# 34  Edith Nourse Rogers Memorial Veterans Hospital...                Texas
# 35                                               AFIP                   SP
# 36  VA Greater Los Angeles Healthcare System, West...           California
# 37  Froedtert Hospital and the Medical College of ...        West Virginia
# 38                        City of Hope Medical Center           California
# 39                                           Allegisa            São Paulo
# 40        Apotheke des Universitätsklinikums Freiburg   Baden-Wuerttemberg
# 41           Washington University School of Medicine             Missouri
# 42  8Surgery and Endoscopy Department of Kharkiv M...    Kharkivska Oblast
# 43  San Francisco VA Medical Center, San Francisco...           California
# 44        ASST DI MONZA; Divisione Malattie Infettive   Comunity Of Madrid
# 45  National Institutes of Health Clinical Center,...             Maryland
# 46   University Hospital Zurich, Division of Oncology                   ZH
# 47                         UMCG - Tuberculosis Center                   NZ
# 48       James J. Peters VA Medical Center, Bronx, NY             New York
# 49       James A. Haley Veterans' Hospital, Tampa, FL              Florida
#
#           mode_country  unique_name_count  unique_state_count  \
# 0              Belgium                  1                   1
# 1        United States                  1                   1
# 2        United States                  1                   1
# 3        United States                  1                   1
# 4   Korea, Republic of                  1                   1
# 5                India                  5                   4
# 6              Germany                  3                   3
# 7        United States                  1                   1
# 8                Italy                 27                  23
# 9        United States                  1                   1
# 10               India                  1                  11
# 11               Italy                 24                  16
# 12              Taiwan                  1                   1
# 13       United States                  1                   1
# 14              Brazil                  1                   1
# 15       United States                 12                  11
# 16       United States                  6                   4
# 17       United States                  1                   1
# 18              Norway                  1                   1
# 19       United States                  1                   1
# 20        South Africa                  3                   1
# 21        South Africa                 13                  10
# 22       United States                  1                   1
# 23       United States                  1                   1
# 24             Germany                  8                   8
# 25      United Kingdom                  1                   1
# 26        South Africa                  2                   2
# 27       United States                  3                   1
# 28               Spain                  1                   1
# 29       United States                 15                  14
# 30       United States                 32                  26
# 31       United States                  1                   1
# 32               Kenya                  5                   5
# 33               Italy                 42                  25
# 34       United States                  1                   1
# 35              Brazil                  4                   3
# 36       United States                  1                   1
# 37       United States                  2                   2
# 38       United States                  1                   1
# 39              Brazil                  1                   1
# 40              France                 12                  12
# 41       United States                  1                   1
# 42             Ukraine                  1                   1
# 43       United States                  2                   1
# 44       United States                 50                  41
# 45       United States                  1                   1
# 46         Switzerland                  1                   1
# 47         Netherlands                  1                   1
# 48       United States                  1                   1
# 49       United States                  4                   4
#
#     unique_zip_count  unique_city_count  unique_country_count
# 0                  1                  1                     1
# 1                  1                  1                     1
# 2                  1                  1                     1
# 3                  1                  1                     1
# 4                  1                  1                     1
# 5                  5                  5                     3
# 6                  3                  3                     3
# 7                  1                  1                     1
# 8                 27                 27                    13
# 9                  1                  1                     1
# 10                13                 14                     8
# 11                18                 25                     3
# 12                 1                  1                     1
# 13                 1                  1                     1
# 14                 1                  1                     1
# 15                11                 11                     6
# 16                 6                  6                     1
# 17                 1                  1                     1
# 18                 1                  1                     1
# 19                 1                  1                     1
# 20                 1                  1                     1
# 21                10                 10                     8
# 22                 1                  1                     1
# 23                 1                  1                     1
# 24                 8                  8                     4
# 25                 1                  1                     1
# 26                 2                  2                     2
# 27                 3                  3                     1
# 28                 1                  1                     1
# 29                15                 15                     1
# 30                32                 32                     3
# 31                 1                  1                     1
# 32                 5                  5                     3
# 33                38                 38                     3
# 34                 1                  1                     1
# 35                 3                  3                     1
# 36                 1                  1                     1
# 37                 2                  2                     1
# 38                 1                  1                     1
# 39                 1                  1                     1
# 40                12                 12                     3
# 41                 1                  1                     1
# 42                 1                  1                     1
# 43                 2                  2                     1
# 44                44                 45                    14
# 45                 1                  1                     1
# 46                 1                  1                     1
# 47                 1                  1                     1
# 48                 1                  1                     1
# 49                 4                  4                     1

# %%
facilities[facilities['nct_id'] == 'NCT01113515']
# Out:
#              nct_id                                             name  \
# 210867  NCT01113515              VA New England Health Care Division
# 210868  NCT01113515                             S.L. Raheja Hospital
# 210869  NCT01113515  Deenanath Mangeshkar Hospital & Research Center
# 210870  NCT01113515              M V Hospital for Diabetes Pvt. Ltd.
# 210871  NCT01113515                            Hospital Kuala Lumpur
#
#                 city                state     zip        country
# 210867    Providence         Rhode Island   02903  United States
# 210868        Mumbai          Maharashtra  400012          India
# 210869          Pune          Maharashtra  411001          India
# 210870       Chennai           Tamil Nadu  600006          India
# 210871  Kuala Lumpur  Wilayah Persekutuan   59100       Malaysia

# %%
final_counts.to_csv('facilities_cleaned.csv', index=False)
